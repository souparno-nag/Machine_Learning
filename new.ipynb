# %%
# %load_ext cudf.pandas
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/llvmlite/binding/ffi.py:141, in _lib_wrapper.__getattr__(self, name)
#     140 try:
# --> 141     return self._fntab[name]
#     142 except KeyError:
#     143     # Lazily wraps new functions as they are requested
#
# KeyError: 'LLVMPY_AddSymbol'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/llvmlite/binding/ffi.py:122, in _lib_wrapper._load_lib(self)
#     119 with _suppress_cleanup_errors(_importlib_resources_path(
#     120         __name__.rpartition(".")[0],
#     121         get_library_name())) as lib_path:
# --> 122     self._lib_handle = ctypes.CDLL(str(lib_path))
# ...

# %%
data = pd.read_csv('breast.csv')
# Out:
# /tmp/ipykernel_11946/3934183946.py:1: DtypeWarning: Columns (27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_table('breast.csv', sep=',')

# %%
data
# Out:
#          CASENUM   REG  MAR_STAT  RACE  ORIGIN  NHIA  SEX  AGE_DX  YR_BRTH  \
# 0        7000002  1502       2.0   1.0     0.0     0    2    60.0   1932.0
# 1        7000046  1502       5.0   1.0     0.0     0    2    76.0   1920.0
# 2        7000058  1502       5.0   1.0     0.0     0    2    70.0   1924.0
# 3        7000068  1502       2.0   1.0     0.0     0    2    59.0   1917.0
# 4        7000082  1502       5.0   1.0     0.0     0    2    65.0   1946.0
# ...          ...   ...       ...   ...     ...   ...  ...     ...      ...
# 712314  42828599  1527       2.0   4.0     0.0     0    2    51.0   1959.0
# 712315  42828615  1527       5.0   2.0     0.0     0    2    94.0   1917.0
# 712316  42828618  1527       1.0   2.0     0.0     0    2    91.0   1919.0
# 712317  42828654  1527       2.0  98.0     1.0     1    2    40.0   1971.0
# 712318  42828662  1527       5.0   1.0     0.0     0    2    90.0   1921.0
#
# ...

# %%
data.columns
# Out:
# Index(['CASENUM', 'REG', 'MAR_STAT', 'RACE', 'ORIGIN', 'NHIA', 'SEX', 'AGE_DX',
#        'YR_BRTH', 'SEQ_NUM',
#        ...
#        'ADJM_6VALUE', 'ADJAJCCSTG', 'CS7SITE', 'CS9SITE', 'CS12SITE', 'HER2',
#        'BRST_SUB', 'PLC_BRTH_CNTRY', 'PLC_BRTH_STATE', 'ANNARBOR'],
#       dtype='object', length=149)
